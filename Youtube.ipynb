# %% [markdown]
# <a href="https://colab.research.google.com/github/cod-md/youtube/blob/main/Youtube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# ...
# <h4 style="color:#888888;">Save Location:</h4>
# Dropdown(options=('/content', '/content/Downloads'), value='/content')
# <button class="p-Widget jupyter-widgets jupyter-button widget-button" id="button-23b75078-6e96-42aa-8038-94621f5bc96e">Refresh</button>
#         <script>
#           document.querySelector("#button-23b75078-6e96-42aa-8038-94621f5bc96e").onclick = (e) => {
#             google.colab.kernel.invokeFunction('button-23b75078-6e96-42aa-8038-94621f5bc96e', [], {})
#             e.preventDefault();
#           };
#         </script>
# *If you want to save in Google Drive please run the cell below.
# <br>
# <button class="p-Widget jupyter-widgets jupyter-button widget-button mod-info" id="button-50d30bf4-184c-4c87-9ca9-d7208f22c436">Download</button>
#         <script>
#           document.querySelector("#button-50d30bf4-184c-4c87-9ca9-d7208f22c436").onclick = (e) => {
#             google.colab.kernel.invokeFunction('button-50d30bf4-184c-4c87-9ca9-d7208f22c436', [], {})
# ...
